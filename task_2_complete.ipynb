# %%
conda create -n python=3.10

# %%
pip install open3d
# Out:
# Collecting open3d
#   Downloading open3d-0.19.0-cp310-cp310-macosx_10_15_universal2.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.18.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/numpy-2.2.3-py3.10-macosx-11.0-arm64.egg (from open3d) (2.2.3)
# Collecting dash>=2.6.0 (from open3d)
#   Downloading dash-3.0.4-py3-none-any.whl.metadata (10 kB)
# Collecting werkzeug>=3.0.0 (from open3d)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting flask>=3.0.0 (from open3d)
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting nbformat>=5.7.0 (from open3d)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting configargparse (from open3d)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting addict (from open3d)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pillow>=9.3.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/pillow-11.1.0-py3.10-macosx-11.0-arm64.egg (from open3d) (11.1.0)
# Collecting matplotlib>=3 (from open3d)
#   Downloading matplotlib-3.10.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/pandas-2.2.3-py3.10-macosx-11.0-arm64.egg (from open3d) (2.2.3)
# Collecting pyyaml>=5.4.1 (from open3d)
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting scikit-learn>=0.21 (from open3d)
#   Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting tqdm (from open3d)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting pyquaternion (from open3d)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Collecting flask>=3.0.0 (from open3d)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug>=3.0.0 (from open3d)
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting plotly>=5.0.0 (from dash>=2.6.0->open3d)
#   Downloading plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: importlib-metadata in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (4.13.2)
# Requirement already satisfied: requests in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/requests-2.32.3-py3.10.egg (from dash>=2.6.0->open3d) (2.32.3)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Using cached retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (75.8.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/jinja2-3.1.6-py3.10.egg (from flask>=3.0.0->open3d) (3.1.6)
# Collecting itsdangerous>=2.1.2 (from flask>=3.0.0->open3d)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/click-8.1.8-py3.10.egg (from flask>=3.0.0->open3d) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/blinker-1.9.0-py3.10.egg (from flask>=3.0.0->open3d) (1.9.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3->open3d)
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3->open3d)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3->open3d)
#   Downloading fonttools-4.57.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3->open3d)
#   Using cached kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d) (25.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3->open3d)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d) (2.9.0.post0)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7.0->open3d)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: jsonschema>=2.6 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/jsonschema-4.23.0-py3.10.egg (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d) (5.14.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/pytz-2025.1-py3.10.egg (from pandas>=1.0->open3d) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/tzdata-2025.1-py3.10.egg (from pandas>=1.0->open3d) (2025.1)
# Collecting scipy>=1.6.0 (from scikit-learn>=0.21->open3d)
#   Using cached scipy-1.15.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.21->open3d)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.21->open3d)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/MarkupSafe-3.0.2-py3.10-macosx-11.0-arm64.egg (from werkzeug>=3.0.0->open3d) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/attrs-25.1.0-py3.10.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/jsonschema_specifications-2024.10.1-py3.10.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/referencing-0.36.2-py3.10.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/rpds_py-0.23.1-py3.10-macosx-11.0-arm64.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.7)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/narwhals-1.29.1-py3.10.egg (from plotly>=5.0.0->dash>=2.6.0->open3d) (1.29.1)
# Requirement already satisfied: six>=1.5 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/charset_normalizer-3.4.1-py3.10.egg (from requests->dash>=2.6.0->open3d) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/idna-3.10-py3.10.egg (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/urllib3-2.3.0-py3.10.egg (from requests->dash>=2.6.0->open3d) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/certifi-2025.1.31-py3.10.egg (from requests->dash>=2.6.0->open3d) (2025.1.31)
# Downloading open3d-0.19.0-cp310-cp310-macosx_10_15_universal2.whl (103.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 MB 509.8 kB/s eta 0:00:0000:0100:06
# Downloading dash-3.0.4-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 580.9 kB/s eta 0:00:00a 0:00:01
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading matplotlib-3.10.1-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 531.9 kB/s eta 0:00:0000:0100:04
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 545.3 kB/s eta 0:00:0000:0100:01
# Using cached werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading fonttools-4.57.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 375.0 kB/s eta 0:00:00a 0:00:10
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Downloading plotly-6.0.1-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 445.2 kB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached scipy-1.15.2-cp310-cp310-macosx_12_0_arm64.whl (30.1 MB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: fastjsonschema, addict, werkzeug, tqdm, threadpoolctl, scipy, retrying, pyyaml, pyquaternion, pyparsing, plotly, kiwisolver, joblib, itsdangerous, fonttools, cycler, contourpy, configargparse, scikit-learn, matplotlib, flask, dash, nbformat, open3d
# Successfully installed addict-2.4.0 configargparse-1.7 contourpy-1.3.2 cycler-0.12.1 dash-3.0.4 fastjsonschema-2.21.1 flask-3.0.3 fonttools-4.57.0 itsdangerous-2.2.0 joblib-1.5.0 kiwisolver-1.4.8 matplotlib-3.10.1 nbformat-5.10.4 open3d-0.19.0 plotly-6.0.1 pyparsing-3.2.3 pyquaternion-0.9.9 pyyaml-6.0.2 retrying-1.3.4 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0 tqdm-4.67.1 werkzeug-3.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install open3d==0.19.0
# Out:
# Collecting open3d==0.19.0
#   Using cached open3d-0.19.0-cp310-cp310-macosx_10_15_universal2.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.18.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (2.0.0)
# Requirement already satisfied: dash>=2.6.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (3.0.4)
# Requirement already satisfied: werkzeug>=3.0.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (3.0.6)
# Requirement already satisfied: flask>=3.0.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (3.0.3)
# Requirement already satisfied: nbformat>=5.7.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (5.10.4)
# Requirement already satisfied: configargparse in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (1.7)
# Requirement already satisfied: addict in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (2.4.0)
# Requirement already satisfied: pillow>=9.3.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/pillow-11.1.0-py3.10-macosx-11.0-arm64.egg (from open3d==0.19.0) (11.1.0)
# Requirement already satisfied: matplotlib>=3 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (3.10.1)
# Requirement already satisfied: pandas>=1.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/pandas-2.2.3-py3.10-macosx-11.0-arm64.egg (from open3d==0.19.0) (2.2.3)
# Requirement already satisfied: pyyaml>=5.4.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (6.0.2)
# Requirement already satisfied: scikit-learn>=0.21 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (1.6.1)
# Requirement already satisfied: tqdm in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (4.67.1)
# Requirement already satisfied: pyquaternion in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from open3d==0.19.0) (0.9.9)
# Requirement already satisfied: plotly>=5.0.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d==0.19.0) (6.0.1)
# Requirement already satisfied: importlib-metadata in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d==0.19.0) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d==0.19.0) (4.13.2)
# Requirement already satisfied: requests in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/requests-2.32.3-py3.10.egg (from dash>=2.6.0->open3d==0.19.0) (2.32.3)
# Requirement already satisfied: retrying in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d==0.19.0) (1.3.4)
# Requirement already satisfied: nest-asyncio in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d==0.19.0) (1.6.0)
# Requirement already satisfied: setuptools in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from dash>=2.6.0->open3d==0.19.0) (75.8.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/jinja2-3.1.6-py3.10.egg (from flask>=3.0.0->open3d==0.19.0) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from flask>=3.0.0->open3d==0.19.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/click-8.1.8-py3.10.egg (from flask>=3.0.0->open3d==0.19.0) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/blinker-1.9.0-py3.10.egg (from flask>=3.0.0->open3d==0.19.0) (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from matplotlib>=3->open3d==0.19.0) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d==0.19.0) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/jsonschema-4.23.0-py3.10.egg (from nbformat>=5.7.0->open3d==0.19.0) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d==0.19.0) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d==0.19.0) (5.14.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/pytz-2025.1-py3.10.egg (from pandas>=1.0->open3d==0.19.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/tzdata-2025.1-py3.10.egg (from pandas>=1.0->open3d==0.19.0) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d==0.19.0) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d==0.19.0) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d==0.19.0) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/MarkupSafe-3.0.2-py3.10-macosx-11.0-arm64.egg (from werkzeug>=3.0.0->open3d==0.19.0) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/attrs-25.1.0-py3.10.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d==0.19.0) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/jsonschema_specifications-2024.10.1-py3.10.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d==0.19.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/referencing-0.36.2-py3.10.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d==0.19.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/rpds_py-0.23.1-py3.10-macosx-11.0-arm64.egg (from jsonschema>=2.6->nbformat>=5.7.0->open3d==0.19.0) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d==0.19.0) (4.3.7)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/narwhals-1.29.1-py3.10.egg (from plotly>=5.0.0->dash>=2.6.0->open3d==0.19.0) (1.29.1)
# Requirement already satisfied: six>=1.5 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3->open3d==0.19.0) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages (from importlib-metadata->dash>=2.6.0->open3d==0.19.0) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/charset_normalizer-3.4.1-py3.10.egg (from requests->dash>=2.6.0->open3d==0.19.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/idna-3.10-py3.10.egg (from requests->dash>=2.6.0->open3d==0.19.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/urllib3-2.3.0-py3.10.egg (from requests->dash>=2.6.0->open3d==0.19.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tapaskumardutta/anaconda3/envs/abcde/lib/python3.10/site-packages/certifi-2025.1.31-py3.10.egg (from requests->dash>=2.6.0->open3d==0.19.0) (2025.1.31)
# Using cached open3d-0.19.0-cp310-cp310-macosx_10_15_universal2.whl (103.1 MB)
# Installing collected packages: open3d
# Successfully installed open3d-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import open3d as o3d
import numpy as np
def align_face_to_axis(pcd, target_axis=np.array([0, 0, 1])):
    # Center the point cloud at the origin
    center = pcd.get_center()
    pcd.translate(-center)

    # Estimate normals
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))

    # Compute average face direction
    normals = np.asarray(pcd.normals)
    face_direction = np.mean(normals, axis=0)
    face_direction /= np.linalg.norm(face_direction)

    # Compute rotation to target axis
    target_axis = target_axis / np.linalg.norm(target_axis)
    rotation_axis = np.cross(face_direction, target_axis)

    if np.linalg.norm(rotation_axis) < 1e-6:
        print("Face already aligned with target axis.")
        return pcd

    rotation_axis /= np.linalg.norm(rotation_axis)
    angle = np.arccos(np.clip(np.dot(face_direction, target_axis), -1.0, 1.0))
    R = o3d.geometry.get_rotation_matrix_from_axis_angle(rotation_axis * angle)

    # Apply rotation around the origin (already centered)
    pcd.rotate(R, center=(0, 0, 0))
    return pcd



import numpy as np
def find_nose_tip(pcd, axis=np.array([0, 0, 1])):
    points = np.asarray(pcd.points)
    # Project all points onto the axis (e.g., Z-axis)
    projections = points @ axis
    max_index = np.argmax(projections)
    nose_tip = points[max_index]
    print(nose_tip)
    print(f"Nose tip coordinates: {nose_tip}")
    return nose_tip

def find_nose_tip_refined(pcd, axis=np.array([0, 0, 1]), k=30):
    points = np.asarray(pcd.points)
    normals = np.asarray(pcd.normals)

    # Project onto the given axis (e.g., Z)
    projections = points @ axis
    max_index = np.argmax(projections)
    rough_tip = points[max_index]

    # Use KDTree to search nearby points for refinement
    pcd_tree = o3d.geometry.KDTreeFlann(pcd)
    [_, idxs, _] = pcd_tree.search_knn_vector_3d(rough_tip, k)
    candidate_points = points[idxs]
    candidate_normals = normals[idxs]

    # Choose point with normal most aligned with axis
    dot_products = candidate_normals @ axis
    best_index = np.argmax(dot_products)
    nose_tip = candidate_points[best_index]

    print(f"Refined nose tip coordinates: {nose_tip}")
    return nose_tip


# Load your point cloud
pcd = o3d.io.read_point_cloud("someone3.ply")
ta=np.array([0, 0, 1])
aligned_pcd = align_face_to_axis(pcd, target_axis=ta)

# Find the nose tip

nose_tip = find_nose_tip(aligned_pcd,ta)

# Add a small sphere at the nose tip for visualization
nose_sphere = o3d.geometry.TriangleMesh.create_sphere(radius=1)
nose_sphere.translate(nose_tip)
nose_sphere.paint_uniform_color([1, 0, 0])  # Red

# Visualize the result
coord_frame = o3d.geometry.TriangleMesh.create_coordinate_frame(size=100)
# Create a plane perpendicular to Z-axis at the nose tip
plane_size = 20  # You can adjust this for visibility
plane = o3d.geometry.TriangleMesh.create_box(width=plane_size, height=plane_size, depth=1e-4)
plane.translate(nose_tip - np.array([plane_size/2, plane_size/2, 0]))
plane.paint_uniform_color([0.2, 0.8, 1.0])  # Light blue

# Visualize everything
o3d.visualization.draw_geometries([aligned_pcd, nose_sphere, coord_frame])
